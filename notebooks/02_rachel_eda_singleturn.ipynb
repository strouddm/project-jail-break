# %%
import pandas as pd

# %%
X_train_sing = pd.read_parquet('../data/raw/wildguardmix/train/wildguard_train.parquet')
X_test_sing = pd.read_parquet('../data/raw/wildguardmix/test/wildguard_test.parquet')

print(X_train_sing['prompt_harm_label'].value_counts())
print(X_train_sing[X_train_sing['response'].isnull()]['prompt_harm_label'].value_counts())

# %%
X_train_sing
